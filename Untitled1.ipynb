# %%
import easygopigo3 as easy
import time
gpg = easy.EasyGoPiGo3()
ds = gpg.init_distance_sensor()
disServ = gpg.init_servo(1)
stepBro = 0
left = 0
right = 0
max = 1200

# %%
class Servo:
    def __init__(self, port, zeroLocation, timePerDegree):
        self.zeroLocation = zeroLocation
        self.gpgServo = gpg.init_servo(port)
        self.gpgServo.rotate_servo(zeroLocation)
        self.currentLocation = 0
        self.timePerDegree = timePerDegree

    def centerServo(self):
        self.gpgServo.rotate_servo(self.zeroLocation)
        self.currentLocation = 0

    def rotateServo(self, degrees):
        self.gpgServo.rotate_servo(self.zeroLocation + degrees)
        self.currentLocation = degrees

    def rotateServoRelative(self, degrees):
        self.rotateServo(self.currentLocation + degrees)

distServo = Servo(1, 69, 0.005)

# %%
"""
def rayCastIRL():
    #scanDirection = distServo.currentLocation % -1
    distServo.rotateServo(-60)
    curAngle = -60
    minAngle = -60
    minDist = 10000
    time.sleep(0.3)
    
    while (curAngle <= 60):
        distServo.rotateServoRelative(5)
        curAngle += 5
        time.sleep(distServo.timePerDegree)
        if(ds.read_mm() < minDist):
            minDist = ds.read_mm()
            minAngle = curAngle
            
    gpg.turn_degrees(minAngle)
    rayCastIRL()
"""

def cap(first, cap):
    if (first > cap):
        return cap
    else:
        return first


def rayCastIRL():
    #distServo.centerServo()
    #time.sleep(0.3)
    #center = ds.read_mm()

    kT = 0.3
    
    distServo.rotateServo(-60)
    time.sleep(0.3)
    left = ds.read_mm()
    distServo.rotateServo(60)
    time.sleep(0.3)
    right = ds.read_mm()
    if(right > left):
        gpg.set_speed(max * 0.50)
        gpg.drive_cm(-5)
        gpg.turn_degrees(-cap(kT * right, 85))
    elif(left > right):
        gpg.set_speed(max * 0.50)
        gpg.drive_cm(-5)
        gpg.turn_degrees(cap(kT * left, 85))
 
    distServo.centerServo()
    time.sleep(0.2)

# %%
def findAngleToWall():
    distServo.centerServo()
    time.sleep(0.3)
    a = ds.read_mm()
    distServo.rotateServo(-20)
    time.sleep(0.1)
    b = ds.read_mm()
    distServo.rotateServo(20)
    time.sleep(0.2)
    c = math.sqrt(a ** 2 + b ** 2 - (2 * a * b * math.cos(20)))
    angle = (a * math.sin(math.radians(45))) / c
    return angle

# %%
#def speen():

# %%
def avoid():
    
    distance = ds.read_mm()
    
    
    kP = 0.7
    
    gpg.set_speed(distance * kP)
    if (distance < 75):
        gpg.stop()
        rayCastIRL()
        gpg.forward()
    if (distance < 150):
        #gpg.stop()
        rayCastIRL()
    else:
        gpg.forward()
    
    """
    gpg.forward()
    rayCastIRL()
    """

# %%
def dontdie():
    while True:
        avoid()

dontdie()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d92fe9f81e4c> in <module>
#       3         avoid()
#       4
# ----> 5 dontdie()
#
# <ipython-input-6-d92fe9f81e4c> in dontdie()
#       1 def dontdie():
#       2     while True:
# ----> 3         avoid()
#       4
#       5 dontdie()
#
# <ipython-input-5-f61e1330c253> in avoid()
#       1 def avoid():
#       2
# ----> 3     distance = ds.read_mm()
#       4
#       5
#
# /usr/local/lib/python3.7/dist-packages/DI_Sensors-1.0.0-py3.7.egg/di_sensors/easy_distance_sensor.py in read_mm(self)
#      89             ifMutexAcquire(self.use_mutex)
#      90             try:
# ---> 91                 mm = self.read_range_single()
#      92             except Exception as e:
#      93                 print(e)
#
# /usr/local/lib/python3.7/dist-packages/DI_Sensors-1.0.0-py3.7.egg/di_sensors/distance_sensor.py in read_range_single(self, safe_infinity)
#      85         if safe_infinity and value < 8190:
#      86             for i in range(3):
# ---> 87                 value = self.VL53L0X.read_range_single_millimeters()
#      88                 if value >= 8190:
#      89                         return value
#
# /usr/local/lib/python3.7/dist-packages/DI_Sensors-1.0.0-py3.7.egg/di_sensors/VL53L0X.py in read_range_single_millimeters(self)
#     874                 self.did_timeout = True
#     875                 raise IOError("read_range_single_millimeters timeout")
# --> 876         return self.read_range_continuous_millimeters()
#     877
#     878     # Set the return signal rate limit check value in units of MCPS (mega counts
#
# /usr/local/lib/python3.7/dist-packages/DI_Sensors-1.0.0-py3.7.egg/di_sensors/VL53L0X.py in read_range_continuous_millimeters(self)
#     691     def read_range_continuous_millimeters(self):
#     692         self.start_timeout()
# --> 693         while ((self.i2c_bus.read_8(RESULT_INTERRUPT_STATUS) & 0x07) == 0):
#     694             if self.check_timeout_expired():
#     695                 self.did_timeout = True
#
# /usr/local/lib/python3.7/dist-packages/Dexter_AutoDetection_and_I2C_Mutex-0.0.0-py3.7.egg/di_i2c.py in read_8(self, reg, signed)
#     275             outArr = []
#     276
# --> 277         val = self.transfer(outArr, 1)
#     278
#     279         value = val[0]
#
# /usr/local/lib/python3.7/dist-packages/Dexter_AutoDetection_and_I2C_Mutex-0.0.0-py3.7.egg/di_i2c.py in transfer(self, outArr, inBytes)
#     200             raise # raise the exception for user-code to deal with
#     201
# --> 202         self.mutex.release() # release the bus mutex
#     203         return return_val    # return data (if read)
#     204
#
# /usr/local/lib/python3.7/dist-packages/Dexter_AutoDetection_and_I2C_Mutex-0.0.0-py3.7.egg/di_mutex.py in release(self)
#      61             self.Handle.close()
#      62             self.Handle = None
# ---> 63             time.sleep(self.LoopTime)
#
# KeyboardInterrupt:
